# %%
import nibabel as nib
import matplotlib.pyplot as plt

img_path = "../data/required_ADNI_Data/AD_3TP_0528_AD-sc-1.5T_strip.img"

""" Function to display row of image slices """
def show_slices(slices):
    fig, axes = plt.subplots(1, len(slices), figsize=(15,5))
    
    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, cmap="gray", origin="lower")


img1 = nib.load(img_path)
data = img1.get_fdata()

print(data.shape)
data = data[:, :, :, 0] 

slice_0 = data[129, :, :]
slice_1 = data[:, 129, :]
slice_2 = data[:, :, 129]
show_slices([slice_0, slice_1, slice_2])
plt.suptitle("Center slices for image")
# Out:
# (256, 256, 256, 1)
# Text(0.5, 0.98, 'Center slices for image')
